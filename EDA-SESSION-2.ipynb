# %% [markdown]
# - we created a data frame using list
# - provided data
# - colunns
# - index added
# - modified the column
# - drop the column
# - shape of thecolumn
# - how to save the data frame

# %% [markdown]
# **how to read a data frame**

# %% [markdown]
# - location
#
# - file name
#
# - extension
#
# - i want to read data1
# - location is not required because python file and data file both are at same location
# - file name:data1
# - extension:.csv

# %%
import pandas as pd

# %%
pd.read_csv('data1.csv')
# Out:
#       names  age    place job  salary
# 0    sonali   25      hyd  ds    1000
# 1  saipriya   56  chennai  de   20000
# 2       sai    7      blr  cs   30000

# %%
pd.read_excel(r"C:\Users\SONALI\app1.xlsx")
# Out:
#       names  age    place job  salary
# 0    sonali   25      hyd  ds    1000
# 1  saipriya   56  chennai  de   20000
# 2       sai    7      blr  cs   30000

# %%
what if the file is saved in a different folder

# %% [markdown]
# $$task$$

# %% [markdown]
# - download visadataset and bank
# - save in a local folder
# - read here
# - first visa data set
# - second bank

# %%
df=pd.read_csv(r"C:\Users\SONALI\Downloads\Visadataset - Visadataset.csv")
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bank_df=pd.read_csv(r"C:\Users\SONALI\Downloads\bank - bank.csv")
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **create data frame using dictionary**

# %%
import pandas as pd
names=['avanish','akash','sonali']
age=[25,90,87]
pd.DataFrame(zip(names,age),columns=['names','age'])
# Out:
#      names  age
# 0  avanish   25
# 1    akash   90
# 2   sonali   87

# %%
dict2={'names':'avanish','ages':25,'city':'hyd'}
pd.DataFrame(dict2,index=[1,2,3])
# Out:
#      names  ages city
# 1  avanish    25  hyd
# 2  avanish    25  hyd
# 3  avanish    25  hyd
